# %% [markdown]
# ### Homework 2: More Exploratory Data Analysis
# ## Gene Expression Data and Election Polls
#
# Due: Thursday, September 29, 2016 11:59 PM
#
#
# #### Submission Instructions
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Make sure to share the private repo with my github account (mdog) and submit the repo path through blackboard.
#
# ---

# %% [markdown]
# ## Introduction
#
# John Tukey wrote in [Exploratory Data Analysis, 1977](http://www.amazon.com/Exploratory-Data-Analysis-Wilder-Tukey/dp/0201076160/ref=pd_bbs_sr_2/103-4466654-5303007?ie=UTF8&s=books&qid=1189739816&sr=8-2): "The greatest value of a picture is when it forces us to notice what we never expected to see." In this assignment we will continue using our exploratory data analysis tools, but apply it to new sets of data: [gene expression](http://en.wikipedia.org/wiki/Gene_expression) and polls from the [2012 Presidental Election](http://en.wikipedia.org/wiki/United_States_presidential_election,_2012) and from the [2014 Senate Midterm Elections](http://en.wikipedia.org/wiki/United_States_Senate_elections,_2014).
#
# **First**: You will use exploratory data analysis and apply the [singular value decomposition](http://en.wikipedia.org/wiki/Singular_value_decomposition) (SVD) to a gene expression data matrix to determine if the the date that the gene expression samples are processed has large effect on the variability seen in the data.
#
# **Second**: You will use the polls from the 2012 Presidential Elections to determine (1) Is there a pollster bias in presidential election polls? and (2) Is the average of polls better than just one poll?
#
# **Finally**: You will use the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to extract the polls for the current 2014 Senate Midterm Elections and provide a preliminary prediction of the result of each state.
#
# #### Data
#
# We will use the following data sets:
#
# 1. A gene expression data set called `exprs_GSE5859.csv` and sample annotation table called `sampleinfo_GSE5859.csv` which are both available on Github in the 2014_data repository: [expression data set](https://github.com/cs109/2014_data/blob/master/exprs_GSE5859.csv) and [sample annotation table](https://github.com/cs109/2014_data/blob/master/sampleinfo_GSE5859.csv).
#
# 2. Polls from the [2012 Presidential Election: Barack Obama vs Mitt Romney](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama). The polls we will use are from the [Huffington Post Pollster](http://elections.huffingtonpost.com/pollster).
#
# 3. Polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api).
#
# ---

# %% [markdown]
# ## Load Python modules

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
from io import StringIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations

# %% [markdown]
# ## Problem 4
#
# In this last problem, we will use the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to create a preliminary prediction of the result of each state.
#
# The HuffPost Pollster API allows you to access the data as a CSV or a JSON response by tacking ".csv" or ".json" at the end of the URLs. For example the 2012 Presidential Election could be accessed as a [.json](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.json) instead of a [.csv](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv)

# %% [markdown]
# #### Problem 4(a)
#
# Read in the polls for **all** of the 2014 Senate Elections using the HuffPost API. For example, we can consider the [2014 Senate race in Kentucky between Mitch McConnell and Alison Grimes](http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes).
#
# To search for the 2014 Senate races, use the `topics` parameter in the API [[read more about topics here](http://elections.huffingtonpost.com/pollster/api)].

# %%
url_str = "http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate"

# %% [markdown]
# To list all the URLs related to the 2014 Senate races using the pollster API, we can use a list comprehension:

# %%
election_urls = [election['url'] + '.csv' for election in requests.get(url_str).json()]
election_urls
# Out:
# ['http://elections.huffingtonpost.com/pollster/2014-delaware-senate-wade-vs-coons.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-massachusetts-senate-herr-vs-markey.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-rhode-island-senate-zaccaria-vs-reed.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-montana-senate-daines-vs-curtis.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-lankford-vs-johnson.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-hawaii-senate-cavasso-vs-schatz.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-kansas-senate-roberts-vs-orman-vs-taylor.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-wyoming-senate.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-tennessee-senate-alexander-vs-ball.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-idaho-senate-risch-vs-mitchell.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-new-jersey-senate-bell-vs-booker.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-new-mexico-senate-weh-vs-udall.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-inhofe-vs-silverstein.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-scott-vs-dickerson.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-graham-vs-hutto.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-texas-senate-cornyn-vs-alameel.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-minnesota-senate-mcfadden-vs-franken.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-maine-senate-collins-vs-bellows.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-south-dakota-senate-rounds-vs-weiland.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-nebraska-senate-sasse-vs-domina.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-georgia-senate-perdue-vs-nunn.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-oregon-senate-wehby-vs-merkley.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-mississippi-senate-cochran-vs-childers.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-iowa-senate-ernst-vs-braley.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-alaska-senate-sullivan-vs-begich.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-illinois-senate-oberweis-vs-durbin.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-colorado-senate-gardner-vs-udall.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-virginia-senate-gillespie-vs-warner.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-north-carolina-senate-tillis-vs-hagan.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-bass-vs-shaheen.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-west-virginia-senate-capito-vs-tennant.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-brown-vs-shaheen.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-cassidy-vs-landrieu.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-michigan-senate-land-vs-peters.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-arkansas-senate-cotton-vs-pryor.csv',
#  'http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes.csv']

# %% [markdown]
# Because there so many Senate races, we can create a dictionary of pandas DataFrames that will be keyed by the name of the election (a string).

# %%
def build_frame(url):
    """
    Returns a pandas DataFrame object containing
    the data returned from the given url
    """
    source = requests.get(url).text
    
    # Use StringIO because pd.DataFrame.from_csv requires .read() method
    s = StringIO(source)
    
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# %%
# Makes a dictionary of pandas DataFrames keyed on election string.
dfs = dict((election.split("/")[-1][:-4], build_frame(election)) for election in election_urls)
# Out:
# /home/haris/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %% [markdown]
# Show the head of the DataFrame containing the polls for the 2014 Senate race in Kentucky between McConnell and Grimes.

# %%
#your code here
dfs['2014-kentucky-senate-mcconnell-vs-grimes'].head()
# Out:
#                                             Pollster Start Date   End Date  \
# 0                                            PPP (D) 2014-10-30 2014-11-01
# 1                                         NBC/Marist 2014-10-27 2014-10-30
# 2  SurveyUSA/Courier-Journal/Herald-Leader/WHAS/WKYT 2014-10-25 2014-10-29
# 3                             POS (R-Crossroads GPS) 2014-10-25 2014-10-27
# 4                                     CBS/NYT/YouGov 2014-10-16 2014-10-23
#
#   Entry Date/Time (ET)  Number of Observations     Population        Mode  \
# 0  2014-11-02 01:44:58                    1503  Likely Voters  IVR/Online
# 1  2014-11-02 14:37:22                     556  Likely Voters  Live Phone
# 2  2014-10-30 23:33:59                     597  Likely Voters  IVR/Online
# 3  2014-10-30 20:56:18                     600  Likely Voters  Live Phone
# 4  2014-10-26 15:00:07                    1502  Likely Voters    Internet
#
#    Grimes  McConnell  Undecided  \
# 0    42.0       50.0        NaN
# 1    41.0       50.0        3.0
# 2    43.0       48.0        6.0
# 3    43.0       50.0        NaN
# 4    39.0       45.0       14.0
#
#                                         Pollster URL  \
# 0  http://elections.huffingtonpost.com/pollster/p...
# 1  http://elections.huffingtonpost.com/pollster/p...
# 2  http://elections.huffingtonpost.com/pollster/p...
# 3  http://elections.huffingtonpost.com/pollster/p...
# 4  http://elections.huffingtonpost.com/pollster/p...
#
#                                           Source URL     Partisan Affiliation  \
# 0  http://www.publicpolicypolling.com/pdf/2014/PP...     Pollster         Dem
# 1  http://newscms.nbcnews.com/sites/newscms/files...  Nonpartisan        None
# 2  http://www.surveyusa.com/client/PollReport.asp...  Nonpartisan        None
# 3  https://www.crossroadsgps.org/wp-content/uploa...      Sponsor         Rep
# 4  https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan        None
#
#    Question Text  Question Iteration
# 0            NaN                   1
# 1            NaN                   1
# 2            NaN                   1
# 3            NaN                   1
# 4            NaN                   1

# %% [markdown]
# #### Problem 4(b)
#
# For each 2014 Senate race, create a preliminary prediction of the result for that state.

# %%
#your code here
x = {}
for keys in dfs:
    info = dfs[keys]
    SenatorA = info.columns[7]
    SenatorB = info.columns[8]
    info.Diff = (info[SenatorA]/100) - (info[SenatorB]/100)
    x[keys] = [SenatorA, SenatorB, np.round(np.mean(info.Diff), 3)]

result = pd.DataFrame(x).T
result.columns = ['SenatorA','SenatorB','Diff']
result['Result'] = np.where(result.Diff >= 0, result.SenatorA, result.SenatorB)

result
# Out:
#                                                 SenatorA     SenatorB   Diff  \
# 2014-alaska-senate-sullivan-vs-begich             Begich     Sullivan  0.003
# 2014-arkansas-senate-cotton-vs-pryor              Cotton        Pryor  0.015
# 2014-colorado-senate-gardner-vs-udall            Gardner        Udall  0.006
# 2014-delaware-senate-wade-vs-coons                 Coons         Wade  0.174
# 2014-georgia-senate-perdue-vs-nunn                  Nunn       Perdue -0.017
# 2014-hawaii-senate-cavasso-vs-schatz              Schatz      Cavasso  0.404
# 2014-idaho-senate-risch-vs-mitchell                Risch     Mitchell  0.298
# 2014-illinois-senate-oberweis-vs-durbin         Oberweis       Durbin -0.124
# 2014-iowa-senate-ernst-vs-braley                  Braley        Ernst      0
# 2014-kansas-senate-roberts-vs-orman-vs-taylor     Taylor      Roberts -0.184
# 2014-kentucky-senate-mcconnell-vs-grimes          Grimes    McConnell  -0.03
# 2014-louisiana-senate-cassidy-vs-landrieu        Cassidy     Landrieu  0.041
# 2014-maine-senate-collins-vs-bellows             Collins      Bellows  0.324
# 2014-massachusetts-senate-herr-vs-markey          Markey         Herr  0.225
# 2014-michigan-senate-land-vs-peters               Peters         Land  0.056
# 2014-minnesota-senate-mcfadden-vs-franken       McFadden      Franken -0.108
# 2014-mississippi-senate-cochran-vs-childers      Cochran     Childers  0.155
# 2014-montana-senate-daines-vs-curtis              Curtis       Daines -0.171
# 2014-nebraska-senate-sasse-vs-domina               Sasse       Domina  0.245
# 2014-new-hampshire-senate-bass-vs-shaheen           Bass      Shaheen -0.153
# 2014-new-hampshire-senate-brown-vs-shaheen       Shaheen        Brown  0.054
# 2014-new-jersey-senate-bell-vs-booker               Bell       Booker -0.137
# 2014-new-mexico-senate-weh-vs-udall                  Weh        Udall -0.146
# 2014-north-carolina-senate-tillis-vs-hagan         Haugh       Tillis -0.354
# 2014-oklahoma-senate-inhofe-vs-silverstein        Inhofe  Silverstein   0.32
# 2014-oklahoma-senate-lankford-vs-johnson        Lankford      Johnson  0.311
# 2014-oregon-senate-wehby-vs-merkley                Wehby      Merkley -0.133
# 2014-rhode-island-senate-zaccaria-vs-reed       Zaccaria         Reed -0.355
# 2014-south-carolina-senate-graham-vs-hutto        Graham        Hutto   0.15
# 2014-south-carolina-senate-scott-vs-dickerson  Dickerson        Scott -0.215
# 2014-south-dakota-senate-rounds-vs-weiland       Weiland       Rounds  -0.13
# 2014-tennessee-senate-alexander-vs-ball        Alexander         Ball   0.19
# 2014-texas-senate-cornyn-vs-alameel               Cornyn      Alameel  0.191
# 2014-virginia-senate-gillespie-vs-warner          Warner    Gillespie  0.155
# 2014-west-virginia-senate-capito-vs-tennant       Capito      Tennant  0.141
# 2014-wyoming-senate                                Hardy         Enzi -0.448
#
#                                                   Result
# 2014-alaska-senate-sullivan-vs-begich             Begich
# 2014-arkansas-senate-cotton-vs-pryor              Cotton
# 2014-colorado-senate-gardner-vs-udall            Gardner
# 2014-delaware-senate-wade-vs-coons                 Coons
# 2014-georgia-senate-perdue-vs-nunn                Perdue
# 2014-hawaii-senate-cavasso-vs-schatz              Schatz
# 2014-idaho-senate-risch-vs-mitchell                Risch
# 2014-illinois-senate-oberweis-vs-durbin           Durbin
# 2014-iowa-senate-ernst-vs-braley                  Braley
# 2014-kansas-senate-roberts-vs-orman-vs-taylor    Roberts
# 2014-kentucky-senate-mcconnell-vs-grimes       McConnell
# 2014-louisiana-senate-cassidy-vs-landrieu        Cassidy
# 2014-maine-senate-collins-vs-bellows             Collins
# 2014-massachusetts-senate-herr-vs-markey          Markey
# 2014-michigan-senate-land-vs-peters               Peters
# 2014-minnesota-senate-mcfadden-vs-franken        Franken
# 2014-mississippi-senate-cochran-vs-childers      Cochran
# 2014-montana-senate-daines-vs-curtis              Daines
# 2014-nebraska-senate-sasse-vs-domina               Sasse
# 2014-new-hampshire-senate-bass-vs-shaheen        Shaheen
# 2014-new-hampshire-senate-brown-vs-shaheen       Shaheen
# 2014-new-jersey-senate-bell-vs-booker             Booker
# 2014-new-mexico-senate-weh-vs-udall                Udall
# 2014-north-carolina-senate-tillis-vs-hagan        Tillis
# 2014-oklahoma-senate-inhofe-vs-silverstein        Inhofe
# 2014-oklahoma-senate-lankford-vs-johnson        Lankford
# 2014-oregon-senate-wehby-vs-merkley              Merkley
# 2014-rhode-island-senate-zaccaria-vs-reed           Reed
# 2014-south-carolina-senate-graham-vs-hutto        Graham
# 2014-south-carolina-senate-scott-vs-dickerson      Scott
# 2014-south-dakota-senate-rounds-vs-weiland        Rounds
# 2014-tennessee-senate-alexander-vs-ball        Alexander
# 2014-texas-senate-cornyn-vs-alameel               Cornyn
# 2014-virginia-senate-gillespie-vs-warner          Warner
# 2014-west-virginia-senate-capito-vs-tennant       Capito
# 2014-wyoming-senate                                 Enzi

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Make sure to share the private repo with my github account (mdog) and submit the repo path through blackboard.
